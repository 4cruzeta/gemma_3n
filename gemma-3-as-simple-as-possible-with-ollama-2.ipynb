# %% [markdown]
# # In this notebook, we will use and showcase the capabilities of Gemma 3n running locally via Ollama.
#
# **Let's try to use the model as much as possible without using GPU. This shows that any computer with few resources can run our code.**

# %%
# !pip install gradio
# !pip install ollama
# Out:
# Collecting gradio
#   Downloading gradio-5.35.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (22.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (4.9.0)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.115.14-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.6.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.10.4 (from gradio)
#   Downloading gradio_client-1.10.4-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.31.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.10.16)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.11.4)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from gradio) (0.25.1)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (6.0.2)
# Collecting ruff>=0.9.3 (from gradio)
#   Downloading ruff-0.12.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.47.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.15.2)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (4.13.2)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.10.4->gradio) (2025.3.2)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.10.4->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (3.18.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (1.1.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.0->gradio) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.0->gradio) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.0->gradio) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.0->gradio) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.0->gradio) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.0->gradio) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.4.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (14.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0,>=1.0->gradio) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0,>=1.0->gradio) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<3.0,>=1.0->gradio) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<3.0,>=1.0->gradio) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.4.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<3.0,>=1.0->gradio) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading gradio-5.35.0-py3-none-any.whl (54.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 MB 31.5 MB/s eta 0:00:00
# Downloading gradio_client-1.10.4-py3-none-any.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.9/323.9 kB 19.1 MB/s eta 0:00:00
# Downloading fastapi-0.115.14-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.5/95.5 kB 5.7 MB/s eta 0:00:00
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.12.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 108.5 MB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.8 MB/s eta 0:00:00
# Downloading tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.5 MB/s eta 0:00:00
# Downloading ffmpy-0.6.0-py3-none-any.whl (5.5 kB)
# Installing collected packages: uvicorn, tomlkit, semantic-version, ruff, python-multipart, groovy, ffmpy, starlette, safehttpx, gradio-client, fastapi, gradio
# Successfully installed fastapi-0.115.14 ffmpy-0.6.0 gradio-5.35.0 gradio-client-1.10.4 groovy-0.1.2 python-multipart-0.0.20 ruff-0.12.1 safehttpx-0.1.6 semantic-version-2.10.0 starlette-0.46.2 tomlkit-0.13.3 uvicorn-0.35.0
# Collecting ollama
#   Downloading ollama-0.5.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: httpx>=0.27 in /usr/local/lib/python3.11/dist-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.11/dist-packages (from ollama) (2.11.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27->ollama) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27->ollama) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27->ollama) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27->ollama) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->ollama) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->ollama) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->ollama) (0.4.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.27->ollama) (1.3.1)
# Downloading ollama-0.5.1-py3-none-any.whl (13 kB)
# Installing collected packages: ollama
# Successfully installed ollama-0.5.1

# %%
# %%time
import os
import sys
import psutil
import subprocess
import logging
import warnings
import gradio as gr
import ollama
from PIL import Image
import io
import base64
import torch
from transformers import AutoProcessor, AutoModelForImageTextToText
# Out:
# 2025-06-29 00:30:21.740242: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751157021.945056      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751157022.003219      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# CPU times: user 23 s, sys: 3.55 s, total: 26.6 s
# Wall time: 36 s

# %%
# Cell: Logger Configuration
# Create a logger
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

# Create file handler and set level to debug
file_handler = logging.FileHandler('app.log')
file_handler.setLevel(logging.INFO)

# Create console handler and set level to error
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.ERROR)

# Create formatters
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# Add formatters to handlers
file_handler.setFormatter(formatter)
console_handler.setFormatter(formatter)

# Add handlers to logger
logger.addHandler(file_handler)
logger.addHandler(console_handler)

# %%
# ==================================================
# _/$\_\%/_/&\_\@/_/$\_\%/_/&\_\@/_/$\_\%/_/&\_\@/_
# ==================================================
#  **********    System Information   *************
# ==================================================
# _/$\_\%/_/&\_\@/_/$\_\%/_/&\_\@/_/$\_\%/_/&\_\@/_
# ==================================================

import os
import sys
import torch
import psutil  

def print_system_info():
    print("System Information:")
    print(f"• Python version: {sys.version}")
    print(f"• Current working directory: {os.getcwd()}")
    print(f"• PyTorch version: {torch.__version__}")

    # Check GPU availability and details
    if torch.cuda.is_available():
        gpu_info = {
            "CUDA Available": torch.cuda.is_available(),
            "CUDA Device Count": torch.cuda.device_count(),
            "Current CUDA Device": torch.cuda.current_device(),
            "Device Name": torch.cuda.get_device_name(torch.cuda.current_device()),
            "Memory Allocated (MB)": round(torch.cuda.memory_allocated(0) / 1024**2, 2),
            "Memory Reserved (MB)": round(torch.cuda.memory_reserved(0) / 1024**2, 2),
        }
        
        print("\n⚡ GPU Detected:")
        for key, value in gpu_info.items():
            print(f"  • {key}: {value}")
    else:
        print("\n😭 No GPU detected. Running on CPU only.")

    # Memory information
    ram = psutil.virtual_memory()
    print("\n🐘 System Memory:")
    print(f"  • Total RAM: {round(ram.total / 1024**2, 2)} MB")
    print(f"  • Available RAM: {round(ram.available / 1024**2, 2)} MB")
    print(f"  • Used RAM: {round(ram.used / 1024**2, 2)} MB")
    print(f"  • RAM Percentage: {ram.percent}% used")

print_system_info()
# Out:
# System Information:
# • Python version: 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# • Current working directory: /kaggle/working
# • PyTorch version: 2.6.0+cu124
#
# 😭 No GPU detected. Running on CPU only.
#
# 🐘 System Memory:
#   • Total RAM: 32102.9 MB
#   • Available RAM: 30344.14 MB
#   • Used RAM: 1301.51 MB
#   • RAM Percentage: 5.5% used

# %%
# %%time
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ############################################################################################# 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# CPU times: user 877 ms, sys: 196 ms, total: 1.07 s
# Wall time: 41 s

# %%
# %%time
process = subprocess.Popen("ollama serve", shell=True)
# Out:
# CPU times: user 717 µs, sys: 112 µs, total: 829 µs
# Wall time: 1.56 ms

# %%
# %%time
# !ollama pull gemma3n:e4b 
# !ollama pull gemma3n:e2b
# Out:
# Your new public key is:
#
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIHUVDOrKH9rykCESAo7u5C9g1ZSVJu//bQbvs94ehBlQ
#
# [GIN] 2025/06/29 - 00:31:20 | 200 |     151.695µs |       127.0.0.1 | HEAD     "/"
# time=2025-06-29T00:31:20.463Z level=INFO source=routes.go:1235 msg="server config" env="map[CUDA_VISIBLE_DEVICES: GPU_DEVICE_ORDINAL: HIP_VISIBLE_DEVICES: HSA_OVERRIDE_GFX_VERSION: HTTPS_PROXY: HTTP_PROXY: NO_PROXY: OLLAMA_CONTEXT_LENGTH:4096 OLLAMA_DEBUG:INFO OLLAMA_FLASH_ATTENTION:false OLLAMA_GPU_OVERHEAD:0 OLLAMA_HOST:http://127.0.0.1:11434 OLLAMA_INTEL_GPU:false OLLAMA_KEEP_ALIVE:5m0s OLLAMA_KV_CACHE_TYPE: OLLAMA_LLM_LIBRARY: OLLAMA_LOAD_TIMEOUT:5m0s OLLAMA_MAX_LOADED_MODELS:0 OLLAMA_MAX_QUEUE:512 OLLAMA_MODELS:/root/.ollama/models OLLAMA_MULTIUSER_CACHE:false OLLAMA_NEW_ENGINE:false OLLAMA_NOHISTORY:false OLLAMA_NOPRUNE:false OLLAMA_NUM_PARALLEL:0 OLLAMA_ORIGINS:[http://localhost https://localhost http://localhost:* https://localhost:* http://127.0.0.1 https://127.0.0.1 http://127.0.0.1:* https://127.0.0.1:* http://0.0.0.0 https://0.0.0.0 http://0.0.0.0:* https://0.0.0.0:* app://* file://* tauri://* vscode-webview://* vscode-file://*] OLLAMA_SCHED_SPREAD:false ROCR_VISIBLE_DEVICES: http_proxy: https_proxy: no_proxy:]"
# time=2025-06-29T00:31:20.464Z level=INFO source=images.go:476 msg="total blobs: 0"
# time=2025-06-29T00:31:20.464Z level=INFO source=images.go:483 msg="total unused blobs removed: 0"
# time=2025-06-29T00:31:20.464Z level=INFO source=routes.go:1288 msg="Listening on 127.0.0.1:11434 (version 0.9.3)"
# time=2025-06-29T00:31:20.465Z level=INFO source=gpu.go:217 msg="looking for compatible GPUs"
# time=2025-06-29T00:31:20.511Z level=INFO source=gpu.go:377 msg="no compatible GPUs were discovered"
# time=2025-06-29T00:31:20.511Z level=INFO source=types.go:130 msg="inference compute" id=0 library=cpu variant="" compute="" driver=0.0 name="" total="31.4 GiB" available="19.1 GiB"
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇
# time=2025-06-29T00:31:21.331Z level=INFO source=download.go:177 msg="downloading 3839a254cf2d in 16 351 MB part(s)"
# pulling manifest ⠏ pulling manifest
# pulling 3839a254cf2d:   0% ▕                  ▏ 178 KB/5.6 GB                  pulling manifest
# pulling 3839a254cf2d:   0% ▕                  ▏  11 MB/5.6 GB                  pulling manifest
# pulling 3839a254cf2d:   1% ▕                  ▏  43 MB/5.6 GB                  pulling manifest
# pulling 3839a254cf2d:   1% ▕                  ▏  79 MB/5.6 GB                  pulling manifest
# pulling 3839a254cf2d:   2% ▕                  ▏  95 MB/5.6 GB                  pulling manifest
# pulling 3839a254cf2d:   2% ▕                  ▏ 131 MB/5.6 GB                  pulling manifest
# pulling 3839a254cf2d:   3% ▕                  ▏ 162 MB/5.6 GB                  pulling manifest
# pulling 3839a254cf2d:   3% ▕                  ▏ 178 MB/5.6 GB                  pulling manifest
# pulling 3839a254cf2d:   4% ▕                  ▏ 207 MB/5.6 GB                  pulling manifest
# pulling 3839a254cf2d:   4% ▕                  ▏ 241 MB/5.6 GB                  pulling manifest
# pulling 3839a254cf2d:   5% ▕                  ▏ 255 MB/5.6 GB                  pulling manifest
# pulling 3839a254cf2d:   5% ▕                  ▏ 287 MB/5.6 GB  271 MB/s     19spulling manifest
# pulling 3839a254cf2d:   6% ▕█                 ▏ 313 MB/5.6 GB  271 MB/s     19spulling manifest
# pulling 3839a254cf2d:   6% ▕█                 ▏ 328 MB/5.6 GB  271 MB/s     19spulling manifest
# pulling 3839a254cf2d:   6% ▕█                 ▏ 353 MB/5.6 GB  271 MB/s     19spulling manifest
# pulling 3839a254cf2d:   7% ▕█                 ▏ 380 MB/5.6 GB  271 MB/s     19spulling manifest
# pulling 3839a254cf2d:   7% ▕█                 ▏ 393 MB/5.6 GB  271 MB/s     19spulling manifest
# pulling 3839a254cf2d:   8% ▕█                 ▏ 423 MB/5.6 GB  271 MB/s     19spulling manifest
# pulling 3839a254cf2d:   8% ▕█                 ▏ 452 MB/5.6 GB  271 MB/s     19spulling manifest
# pulling 3839a254cf2d:   8% ▕█                 ▏ 467 MB/5.6 GB  271 MB/s     18spulling manifest
# pulling 3839a254cf2d:   9% ▕█                 ▏ 497 MB/5.6 GB  271 MB/s     18spulling manifest
# pulling 3839a254cf2d:   9% ▕█                 ▏ 528 MB/5.6 GB  256 MB/s     19spulling manifest
# pulling 3839a254cf2d:  10% ▕█                 ▏ 543 MB/5.6 GB  256 MB/s     19spulling manifest
# pulling 3839a254cf2d:  10% ▕█                 ▏ 573 MB/5.6 GB  256 MB/s     19spulling manifest
# pulling 3839a254cf2d:  11% ▕█                 ▏ 603 MB/5.6 GB  256 MB/s     19spulling manifest
# pulling 3839a254cf2d:  11% ▕█                 ▏ 618 MB/5.6 GB  256 MB/s     19spulling manifest
# pulling 3839a254cf2d:  12% ▕██                ▏ 649 MB/5.6 GB  256 MB/s     19spulling manifest
# pulling 3839a254cf2d:  12% ▕██                ▏ 678 MB/5.6 GB  256 MB/s     19spulling manifest
# pulling 3839a254cf2d:  13% ▕██                ▏ 706 MB/5.6 GB  256 MB/s     19spulling manifest
# pulling 3839a254cf2d:  13% ▕██                ▏ 724 MB/5.6 GB  256 MB/s     19spulling manifest
# pulling 3839a254cf2d:  13% ▕██                ▏ 750 MB/5.6 GB  256 MB/s     18spulling manifest
# pulling 3839a254cf2d:  14% ▕██                ▏ 766 MB/5.6 GB  255 MB/s     19spulling manifest
# pulling 3839a254cf2d:  14% ▕██                ▏ 797 MB/5.6 GB  255 MB/s     18spulling manifest
# pulling 3839a254cf2d:  15% ▕██                ▏ 829 MB/5.6 GB  255 MB/s     18spulling manifest
# pulling 3839a254cf2d:  15% ▕██                ▏ 845 MB/5.6 GB  255 MB/s     18spulling manifest
# pulling 3839a254cf2d:  16% ▕██                ▏ 875 MB/5.6 GB  255 MB/s     18spulling manifest
# pulling 3839a254cf2d:  16% ▕██                ▏ 904 MB/5.6 GB  255 MB/s     18spulling manifest
# pulling 3839a254cf2d:  16% ▕██                ▏ 918 MB/5.6 GB  255 MB/s     18spulling manifest
# pulling 3839a254cf2d:  17% ▕███               ▏ 944 MB/5.6 GB  255 MB/s     18spulling manifest
# pulling 3839a254cf2d:  17% ▕███               ▏ 970 MB/5.6 GB  255 MB/s     18spulling manifest
# pulling 3839a254cf2d:  17% ▕███               ▏ 982 MB/5.6 GB  255 MB/s     18spulling manifest
# pulling 3839a254cf2d:  18% ▕███               ▏ 1.0 GB/5.6 GB  253 MB/s     18spulling manifest
# pulling 3839a254cf2d:  19% ▕███               ▏ 1.0 GB/5.6 GB  253 MB/s     18spulling manifest
# pulling 3839a254cf2d:  19% ▕███               ▏ 1.1 GB/5.6 GB  253 MB/s     18spulling manifest
# pulling 3839a254cf2d:  19% ▕███               ▏ 1.1 GB/5.6 GB  253 MB/s     17spulling manifest
# pulling 3839a254cf2d:  20% ▕███               ▏ 1.1 GB/5.6 GB  253 MB/s     17spulling manifest
# pulling 3839a254cf2d:  20% ▕███               ▏ 1.1 GB/5.6 GB  253 MB/s     17spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  253 MB/s     17spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  253 MB/s     17spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  253 MB/s     17spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  253 MB/s     17spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  233 MB/s     19spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  233 MB/s     19spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  233 MB/s     19spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  233 MB/s     19spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  233 MB/s     19spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  233 MB/s     19spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  233 MB/s     18spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  233 MB/s     18spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  233 MB/s     18spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  233 MB/s     18spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  198 MB/s     22spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  198 MB/s     22spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  198 MB/s     22spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  198 MB/s     22spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  198 MB/s     22spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  198 MB/s     22spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  198 MB/s     22spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  198 MB/s     22spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  198 MB/s     22spulling manifest
# pulling 3839a254cf2d:  21% ▕███               ▏ 1.2 GB/5.6 GB  198 MB/s     22spulling manifest
# pulling 3839a254cf2d:  22% ▕███               ▏ 1.2 GB/5.6 GB  198 MB/s     22spulling manifest
# pulling 3839a254cf2d:  22% ▕███               ▏ 1.2 GB/5.6 GB  172 MB/s     25spulling manifest
# pulling 3839a254cf2d:  22% ▕███               ▏ 1.2 GB/5.6 GB  172 MB/s     25spulling manifest
# pulling 3839a254cf2d:  22% ▕███               ▏ 1.2 GB/5.6 GB  172 MB/s     25spulling manifest
# pulling 3839a254cf2d:  22% ▕███               ▏ 1.2 GB/5.6 GB  172 MB/s     25spulling manifest
# pulling 3839a254cf2d:  22% ▕███               ▏ 1.2 GB/5.6 GB  172 MB/s     25spulling manifest
# pulling 3839a254cf2d:  22% ▕███               ▏ 1.2 GB/5.6 GB  172 MB/s     25spulling manifest
# pulling 3839a254cf2d:  22% ▕███               ▏ 1.2 GB/5.6 GB  172 MB/s     25spulling manifest
# pulling 3839a254cf2d:  22% ▕███               ▏ 1.2 GB/5.6 GB  172 MB/s     25spulling manifest
# pulling 3839a254cf2d:  22% ▕███               ▏ 1.2 GB/5.6 GB  172 MB/s     25spulling manifest
# pulling 3839a254cf2d:  22% ▕███               ▏ 1.2 GB/5.6 GB  172 MB/s     25spulling manifest
# pulling 3839a254cf2d:  23% ▕████              ▏ 1.3 GB/5.6 GB  156 MB/s     27spulling manifest
# pulling 3839a254cf2d:  23% ▕████              ▏ 1.3 GB/5.6 GB  156 MB/s     27spulling manifest
# pulling 3839a254cf2d:  23% ▕████              ▏ 1.3 GB/5.6 GB  156 MB/s     27spulling manifest
# pulling 3839a254cf2d:  24% ▕████              ▏ 1.3 GB/5.6 GB  156 MB/s     27spulling manifest
# pulling 3839a254cf2d:  24% ▕████              ▏ 1.4 GB/5.6 GB  156 MB/s     27spulling manifest
# pulling 3839a254cf2d:  25% ▕████              ▏ 1.4 GB/5.6 GB  156 MB/s     27spulling manifest
# pulling 3839a254cf2d:  25% ▕████              ▏ 1.4 GB/5.6 GB  156 MB/s     26spulling manifest
# pulling 3839a254cf2d:  26% ▕████              ▏ 1.4 GB/5.6 GB  156 MB/s     26spulling manifest
# pulling 3839a254cf2d:  26% ▕████              ▏ 1.5 GB/5.6 GB  156 MB/s     26spulling manifest
# pulling 3839a254cf2d:  27% ▕████              ▏ 1.5 GB/5.6 GB  156 MB/s     26spulling manifest
# pulling 3839a254cf2d:  27% ▕████              ▏ 1.5 GB/5.6 GB  169 MB/s     24spulling manifest
# pulling 3839a254cf2d:  28% ▕█████             ▏ 1.6 GB/5.6 GB  169 MB/s     23spulling manifest
# pulling 3839a254cf2d:  29% ▕█████             ▏ 1.6 GB/5.6 GB  169 MB/s     23spulling manifest
# pulling 3839a254cf2d:  29% ▕█████             ▏ 1.6 GB/5.6 GB  169 MB/s     23spulling manifest
# pulling 3839a254cf2d:  30% ▕█████             ▏ 1.7 GB/5.6 GB  169 MB/s     23spulling manifest
# pulling 3839a254cf2d:  30% ▕█████             ▏ 1.7 GB/5.6 GB  169 MB/s     23spulling manifest
# pulling 3839a254cf2d:  31% ▕█████             ▏ 1.7 GB/5.6 GB  169 MB/s     22spulling manifest
# pulling 3839a254cf2d:  31% ▕█████             ▏ 1.8 GB/5.6 GB  169 MB/s     22spulling manifest
# pulling 3839a254cf2d:  32% ▕█████             ▏ 1.8 GB/5.6 GB  169 MB/s     22spulling manifest
# pulling 3839a254cf2d:  32% ▕█████             ▏ 1.8 GB/5.6 GB  169 MB/s     22spulling manifest
# pulling 3839a254cf2d:  33% ▕█████             ▏ 1.9 GB/5.6 GB  177 MB/s     21spulling manifest
# pulling 3839a254cf2d:  34% ▕██████            ▏ 1.9 GB/5.6 GB  177 MB/s     21spulling manifest
# pulling 3839a254cf2d:  34% ▕██████            ▏ 1.9 GB/5.6 GB  177 MB/s     20spulling manifest
# pulling 3839a254cf2d:  35% ▕██████            ▏ 2.0 GB/5.6 GB  177 MB/s     20spulling manifest
# pulling 3839a254cf2d:  35% ▕██████            ▏ 2.0 GB/5.6 GB  177 MB/s     20spulling manifest
# pulling 3839a254cf2d:  36% ▕██████            ▏ 2.0 GB/5.6 GB  177 MB/s     20spulling manifest
# pulling 3839a254cf2d:  36% ▕██████            ▏ 2.0 GB/5.6 GB  177 MB/s     20spulling manifest
# pulling 3839a254cf2d:  37% ▕██████            ▏ 2.1 GB/5.6 GB  177 MB/s     20spulling manifest
# pulling 3839a254cf2d:  37% ▕██████            ▏ 2.1 GB/5.6 GB  177 MB/s     20spulling manifest
# pulling 3839a254cf2d:  37% ▕██████            ▏ 2.1 GB/5.6 GB  177 MB/s     19spulling manifest
# pulling 3839a254cf2d:  38% ▕██████            ▏ 2.1 GB/5.6 GB  178 MB/s     19spulling manifest
# pulling 3839a254cf2d:  38% ▕██████            ▏ 2.1 GB/5.6 GB  178 MB/s     19spulling manifest
# pulling 3839a254cf2d:  38% ▕██████            ▏ 2.2 GB/5.6 GB  178 MB/s     19spulling manifest
# pulling 3839a254cf2d:  38% ▕██████            ▏ 2.2 GB/5.6 GB  178 MB/s     19spulling manifest
# pulling 3839a254cf2d:  39% ▕███████           ▏ 2.2 GB/5.6 GB  178 MB/s     19spulling manifest
# pulling 3839a254cf2d:  39% ▕███████           ▏ 2.2 GB/5.6 GB  178 MB/s     19spulling manifest
# pulling 3839a254cf2d:  40% ▕███████           ▏ 2.2 GB/5.6 GB  178 MB/s     19spulling manifest
# pulling 3839a254cf2d:  40% ▕███████           ▏ 2.3 GB/5.6 GB  178 MB/s     18spulling manifest
# pulling 3839a254cf2d:  41% ▕███████           ▏ 2.3 GB/5.6 GB  178 MB/s     18spulling manifest
# pulling 3839a254cf2d:  41% ▕███████           ▏ 2.3 GB/5.6 GB  178 MB/s     18spulling manifest
# pulling 3839a254cf2d:  41% ▕███████           ▏ 2.3 GB/5.6 GB  178 MB/s     18spulling manifest
# pulling 3839a254cf2d:  42% ▕███████           ▏ 2.3 GB/5.6 GB  173 MB/s     18spulling manifest
# pulling 3839a254cf2d:  42% ▕███████           ▏ 2.4 GB/5.6 GB  173 MB/s     18spulling manifest
# pulling 3839a254cf2d:  42% ▕███████           ▏ 2.4 GB/5.6 GB  173 MB/s     18spulling manifest
# pulling 3839a254cf2d:  43% ▕███████           ▏ 2.4 GB/5.6 GB  173 MB/s     18spulling manifest
# pulling 3839a254cf2d:  43% ▕███████           ▏ 2.4 GB/5.6 GB  173 MB/s     18spulling manifest
# pulling 3839a254cf2d:  43% ▕███████           ▏ 2.4 GB/5.6 GB  173 MB/s     18spulling manifest
# pulling 3839a254cf2d:  43% ▕███████           ▏ 2.4 GB/5.6 GB  173 MB/s     18spulling manifest
# pulling 3839a254cf2d:  44% ▕███████           ▏ 2.5 GB/5.6 GB  173 MB/s     18spulling manifest
# pulling 3839a254cf2d:  44% ▕███████           ▏ 2.5 GB/5.6 GB  173 MB/s     18spulling manifest
# pulling 3839a254cf2d:  44% ▕███████           ▏ 2.5 GB/5.6 GB  173 MB/s     17spulling manifest
# pulling 3839a254cf2d:  45% ▕████████          ▏ 2.5 GB/5.6 GB  165 MB/s     18spulling manifest
# pulling 3839a254cf2d:  45% ▕████████          ▏ 2.5 GB/5.6 GB  165 MB/s     18spulling manifest
# pulling 3839a254cf2d:  45% ▕████████          ▏ 2.5 GB/5.6 GB  165 MB/s     18spulling manifest
# pulling 3839a254cf2d:  45% ▕████████          ▏ 2.5 GB/5.6 GB  165 MB/s     18spulling manifest
# pulling 3839a254cf2d:  45% ▕████████          ▏ 2.5 GB/5.6 GB  165 MB/s     18spulling manifest
# pulling 3839a254cf2d:  45% ▕████████          ▏ 2.6 GB/5.6 GB  165 MB/s     18spulling manifest
# pulling 3839a254cf2d:  46% ▕████████          ▏ 2.6 GB/5.6 GB  165 MB/s     18spulling manifest
# pulling 3839a254cf2d:  46% ▕████████          ▏ 2.6 GB/5.6 GB  165 MB/s     18spulling manifest
# pulling 3839a254cf2d:  46% ▕████████          ▏ 2.6 GB/5.6 GB  165 MB/s     18spulling manifest
# pulling 3839a254cf2d:  46% ▕████████          ▏ 2.6 GB/5.6 GB  165 MB/s     18spulling manifest
# pulling 3839a254cf2d:  47% ▕████████          ▏ 2.6 GB/5.6 GB  161 MB/s     18spulling manifest
# pulling 3839a254cf2d:  47% ▕████████          ▏ 2.6 GB/5.6 GB  161 MB/s     18spulling manifest
# pulling 3839a254cf2d:  47% ▕████████          ▏ 2.7 GB/5.6 GB  161 MB/s     18spulling manifest
# pulling 3839a254cf2d:  48% ▕████████          ▏ 2.7 GB/5.6 GB  161 MB/s     18spulling manifest
# pulling 3839a254cf2d:  48% ▕████████          ▏ 2.7 GB/5.6 GB  161 MB/s     18spulling manifest
# pulling 3839a254cf2d:  48% ▕████████          ▏ 2.7 GB/5.6 GB  161 MB/s     17spulling manifest
# pulling 3839a254cf2d:  49% ▕████████          ▏ 2.7 GB/5.6 GB  161 MB/s     17spulling manifest
# pulling 3839a254cf2d:  49% ▕████████          ▏ 2.8 GB/5.6 GB  161 MB/s     17spulling manifest
# pulling 3839a254cf2d:  49% ▕████████          ▏ 2.8 GB/5.6 GB  161 MB/s     17spulling manifest
# pulling 3839a254cf2d:  50% ▕████████          ▏ 2.8 GB/5.6 GB  161 MB/s     17spulling manifest
# pulling 3839a254cf2d:  50% ▕█████████         ▏ 2.8 GB/5.6 GB  181 MB/s     15spulling manifest
# pulling 3839a254cf2d:  50% ▕█████████         ▏ 2.8 GB/5.6 GB  181 MB/s     15spulling manifest
# pulling 3839a254cf2d:  51% ▕█████████         ▏ 2.8 GB/5.6 GB  181 MB/s     15spulling manifest
# pulling 3839a254cf2d:  51% ▕█████████         ▏ 2.9 GB/5.6 GB  181 MB/s     15spulling manifest
# pulling 3839a254cf2d:  51% ▕█████████         ▏ 2.9 GB/5.6 GB  181 MB/s     15spulling manifest
# pulling 3839a254cf2d:  52% ▕█████████         ▏ 2.9 GB/5.6 GB  181 MB/s     15spulling manifest
# pulling 3839a254cf2d:  52% ▕█████████         ▏ 2.9 GB/5.6 GB  181 MB/s     14spulling manifest
# pulling 3839a254cf2d:  52% ▕█████████         ▏ 2.9 GB/5.6 GB  181 MB/s     14spulling manifest
# pulling 3839a254cf2d:  52% ▕█████████         ▏ 3.0 GB/5.6 GB  181 MB/s     14spulling manifest
# pulling 3839a254cf2d:  53% ▕█████████         ▏ 3.0 GB/5.6 GB  181 MB/s     14spulling manifest
# pulling 3839a254cf2d:  53% ▕█████████         ▏ 3.0 GB/5.6 GB  181 MB/s     14spulling manifest
# pulling 3839a254cf2d:  54% ▕█████████         ▏ 3.0 GB/5.6 GB  198 MB/s     13spulling manifest
# pulling 3839a254cf2d:  54% ▕█████████         ▏ 3.0 GB/5.6 GB  198 MB/s     12spulling manifest
# pulling 3839a254cf2d:  54% ▕█████████         ▏ 3.1 GB/5.6 GB  198 MB/s     12spulling manifest
# pulling 3839a254cf2d:  55% ▕█████████         ▏ 3.1 GB/5.6 GB  198 MB/s     12spulling manifest
# pulling 3839a254cf2d:  55% ▕█████████         ▏ 3.1 GB/5.6 GB  198 MB/s     12spulling manifest
# pulling 3839a254cf2d:  55% ▕█████████         ▏ 3.1 GB/5.6 GB  198 MB/s     12spulling manifest
# pulling 3839a254cf2d:  56% ▕██████████        ▏ 3.1 GB/5.6 GB  198 MB/s     12spulling manifest
# pulling 3839a254cf2d:  56% ▕██████████        ▏ 3.2 GB/5.6 GB  198 MB/s     12spulling manifest
# pulling 3839a254cf2d:  57% ▕██████████        ▏ 3.2 GB/5.6 GB  198 MB/s     12spulling manifest
# pulling 3839a254cf2d:  58% ▕██████████        ▏ 3.2 GB/5.6 GB  198 MB/s     11spulling manifest
# pulling 3839a254cf2d:  59% ▕██████████        ▏ 3.3 GB/5.6 GB  225 MB/s     10spulling manifest
# pulling 3839a254cf2d:  60% ▕██████████        ▏ 3.4 GB/5.6 GB  225 MB/s     10spulling manifest
# pulling 3839a254cf2d:  60% ▕██████████        ▏ 3.4 GB/5.6 GB  225 MB/s      9spulling manifest
# pulling 3839a254cf2d:  61% ▕██████████        ▏ 3.4 GB/5.6 GB  225 MB/s      9spulling manifest
# pulling 3839a254cf2d:  61% ▕███████████       ▏ 3.4 GB/5.6 GB  225 MB/s      9spulling manifest
# pulling 3839a254cf2d:  62% ▕███████████       ▏ 3.5 GB/5.6 GB  225 MB/s      9spulling manifest
# pulling 3839a254cf2d:  62% ▕███████████       ▏ 3.5 GB/5.6 GB  225 MB/s      9spulling manifest
# pulling 3839a254cf2d:  62% ▕███████████       ▏ 3.5 GB/5.6 GB  225 MB/s      9spulling manifest
# pulling 3839a254cf2d:  63% ▕███████████       ▏ 3.5 GB/5.6 GB  225 MB/s      9spulling manifest
# pulling 3839a254cf2d:  63% ▕███████████       ▏ 3.6 GB/5.6 GB  225 MB/s      9spulling manifest
# pulling 3839a254cf2d:  63% ▕███████████       ▏ 3.6 GB/5.6 GB  225 MB/s      9spulling manifest
# pulling 3839a254cf2d:  64% ▕███████████       ▏ 3.6 GB/5.6 GB  225 MB/s      9spulling manifest
# pulling 3839a254cf2d:  64% ▕███████████       ▏ 3.6 GB/5.6 GB  225 MB/s      8spulling manifest
# pulling 3839a254cf2d:  65% ▕███████████       ▏ 3.6 GB/5.6 GB  225 MB/s      8spulling manifest
# pulling 3839a254cf2d:  65% ▕███████████       ▏ 3.7 GB/5.6 GB  225 MB/s      8spulling manifest
# pulling 3839a254cf2d:  65% ▕███████████       ▏ 3.7 GB/5.6 GB  225 MB/s      8spulling manifest
# pulling 3839a254cf2d:  66% ▕███████████       ▏ 3.7 GB/5.6 GB  225 MB/s      8spulling manifest
# pulling 3839a254cf2d:  66% ▕███████████       ▏ 3.7 GB/5.6 GB  225 MB/s      8spulling manifest
# pulling 3839a254cf2d:  67% ▕███████████       ▏ 3.7 GB/5.6 GB  225 MB/s      8spulling manifest
# pulling 3839a254cf2d:  67% ▕████████████      ▏ 3.8 GB/5.6 GB  225 MB/s      8spulling manifest
# pulling 3839a254cf2d:  67% ▕████████████      ▏ 3.8 GB/5.6 GB  213 MB/s      8spulling manifest
# pulling 3839a254cf2d:  68% ▕████████████      ▏ 3.8 GB/5.6 GB  213 MB/s      8spulling manifest
# pulling 3839a254cf2d:  68% ▕████████████      ▏ 3.8 GB/5.6 GB  213 MB/s      8spulling manifest
# pulling 3839a254cf2d:  69% ▕████████████      ▏ 3.9 GB/5.6 GB  213 MB/s      8spulling manifest
# pulling 3839a254cf2d:  69% ▕████████████      ▏ 3.9 GB/5.6 GB  213 MB/s      8spulling manifest
# pulling 3839a254cf2d:  69% ▕████████████      ▏ 3.9 GB/5.6 GB  213 MB/s      8spulling manifest
# pulling 3839a254cf2d:  70% ▕████████████      ▏ 3.9 GB/5.6 GB  213 MB/s      7spulling manifest
# pulling 3839a254cf2d:  70% ▕████████████      ▏ 3.9 GB/5.6 GB  213 MB/s      7spulling manifest
# pulling 3839a254cf2d:  71% ▕████████████      ▏ 4.0 GB/5.6 GB  213 MB/s      7spulling manifest
# pulling 3839a254cf2d:  71% ▕████████████      ▏ 4.0 GB/5.6 GB  213 MB/s      7spulling manifest
# pulling 3839a254cf2d:  71% ▕████████████      ▏ 4.0 GB/5.6 GB  210 MB/s      7spulling manifest
# pulling 3839a254cf2d:  72% ▕████████████      ▏ 4.0 GB/5.6 GB  210 MB/s      7spulling manifest
# pulling 3839a254cf2d:  72% ▕████████████      ▏ 4.1 GB/5.6 GB  210 MB/s      7spulling manifest
# pulling 3839a254cf2d:  73% ▕█████████████     ▏ 4.1 GB/5.6 GB  210 MB/s      7spulling manifest
# pulling 3839a254cf2d:  73% ▕█████████████     ▏ 4.1 GB/5.6 GB  210 MB/s      7spulling manifest
# pulling 3839a254cf2d:  73% ▕█████████████     ▏ 4.1 GB/5.6 GB  210 MB/s      7spulling manifest
# pulling 3839a254cf2d:  74% ▕█████████████     ▏ 4.2 GB/5.6 GB  210 MB/s      6spulling manifest
# pulling 3839a254cf2d:  74% ▕█████████████     ▏ 4.2 GB/5.6 GB  210 MB/s      6spulling manifest
# pulling 3839a254cf2d:  75% ▕█████████████     ▏ 4.2 GB/5.6 GB  210 MB/s      6spulling manifest
# pulling 3839a254cf2d:  77% ▕█████████████     ▏ 4.3 GB/5.6 GB  210 MB/s      6spulling manifest
# pulling 3839a254cf2d:  77% ▕█████████████     ▏ 4.3 GB/5.6 GB  210 MB/s      6spulling manifest
# pulling 3839a254cf2d:  79% ▕██████████████    ▏ 4.4 GB/5.6 GB  229 MB/s      5spulling manifest
# pulling 3839a254cf2d:  80% ▕██████████████    ▏ 4.5 GB/5.6 GB  229 MB/s      4spulling manifest
# pulling 3839a254cf2d:  81% ▕██████████████    ▏ 4.5 GB/5.6 GB  229 MB/s      4spulling manifest
# pulling 3839a254cf2d:  81% ▕██████████████    ▏ 4.6 GB/5.6 GB  229 MB/s      4spulling manifest
# pulling 3839a254cf2d:  82% ▕██████████████    ▏ 4.6 GB/5.6 GB  229 MB/s      4spulling manifest
# pulling 3839a254cf2d:  82% ▕██████████████    ▏ 4.6 GB/5.6 GB  229 MB/s      4spulling manifest
# pulling 3839a254cf2d:  83% ▕██████████████    ▏ 4.7 GB/5.6 GB  229 MB/s      4spulling manifest
# pulling 3839a254cf2d:  84% ▕███████████████   ▏ 4.7 GB/5.6 GB  229 MB/s      3spulling manifest
# pulling 3839a254cf2d:  84% ▕███████████████   ▏ 4.7 GB/5.6 GB  229 MB/s      3spulling manifest
# pulling 3839a254cf2d:  85% ▕███████████████   ▏ 4.8 GB/5.6 GB  229 MB/s      3spulling manifest
# pulling 3839a254cf2d:  85% ▕███████████████   ▏ 4.8 GB/5.6 GB  254 MB/s      3spulling manifest
# pulling 3839a254cf2d:  86% ▕███████████████   ▏ 4.8 GB/5.6 GB  254 MB/s      3spulling manifest
# pulling 3839a254cf2d:  86% ▕███████████████   ▏ 4.8 GB/5.6 GB  254 MB/s      3spulling manifest
# pulling 3839a254cf2d:  87% ▕███████████████   ▏ 4.9 GB/5.6 GB  254 MB/s      2spulling manifest
# pulling 3839a254cf2d:  87% ▕███████████████   ▏ 4.9 GB/5.6 GB  254 MB/s      2spulling manifest
# pulling 3839a254cf2d:  87% ▕███████████████   ▏ 4.9 GB/5.6 GB  254 MB/s      2spulling manifest
# pulling 3839a254cf2d:  88% ▕███████████████   ▏ 4.9 GB/5.6 GB  254 MB/s      2spulling manifest
# pulling 3839a254cf2d:  88% ▕███████████████   ▏ 5.0 GB/5.6 GB  254 MB/s      2spulling manifest
# pulling 3839a254cf2d:  89% ▕███████████████   ▏ 5.0 GB/5.6 GB  254 MB/s      2spulling manifest
# pulling 3839a254cf2d:  89% ▕████████████████  ▏ 5.0 GB/5.6 GB  254 MB/s      2spulling manifest
# pulling 3839a254cf2d:  90% ▕████████████████  ▏ 5.0 GB/5.6 GB  266 MB/s      2spulling manifest
# pulling 3839a254cf2d:  90% ▕████████████████  ▏ 5.1 GB/5.6 GB  266 MB/s      2spulling manifest
# pulling 3839a254cf2d:  90% ▕████████████████  ▏ 5.1 GB/5.6 GB  266 MB/s      2spulling manifest
# pulling 3839a254cf2d:  91% ▕████████████████  ▏ 5.1 GB/5.6 GB  266 MB/s      1spulling manifest
# pulling 3839a254cf2d:  91% ▕████████████████  ▏ 5.1 GB/5.6 GB  266 MB/s      1spulling manifest
# pulling 3839a254cf2d:  92% ▕████████████████  ▏ 5.1 GB/5.6 GB  266 MB/s      1spulling manifest
# pulling 3839a254cf2d:  92% ▕████████████████  ▏ 5.2 GB/5.6 GB  266 MB/s      1spulling manifest
# pulling 3839a254cf2d:  92% ▕████████████████  ▏ 5.2 GB/5.6 GB  266 MB/s      1spulling manifest
# pulling 3839a254cf2d:  93% ▕████████████████  ▏ 5.2 GB/5.6 GB  266 MB/s      1spulling manifest
# pulling 3839a254cf2d:  93% ▕████████████████  ▏ 5.2 GB/5.6 GB  266 MB/s      1spulling manifest
# pulling 3839a254cf2d:  93% ▕████████████████  ▏ 5.3 GB/5.6 GB  270 MB/s      1spulling manifest
# pulling 3839a254cf2d:  94% ▕████████████████  ▏ 5.3 GB/5.6 GB  270 MB/s      1spulling manifest
# pulling 3839a254cf2d:  94% ▕████████████████  ▏ 5.3 GB/5.6 GB  270 MB/s      1spulling manifest
# pulling 3839a254cf2d:  95% ▕█████████████████ ▏ 5.3 GB/5.6 GB  270 MB/s      1spulling manifest
# pulling 3839a254cf2d:  95% ▕█████████████████ ▏ 5.3 GB/5.6 GB  270 MB/s      1spulling manifest
# pulling 3839a254cf2d:  95% ▕█████████████████ ▏ 5.4 GB/5.6 GB  270 MB/s      0spulling manifest
# pulling 3839a254cf2d:  96% ▕█████████████████ ▏ 5.4 GB/5.6 GB  270 MB/s      0spulling manifest
# pulling 3839a254cf2d:  96% ▕█████████████████ ▏ 5.4 GB/5.6 GB  270 MB/s      0spulling manifest
# pulling 3839a254cf2d:  96% ▕█████████████████ ▏ 5.4 GB/5.6 GB  270 MB/s      0spulling manifest
# pulling 3839a254cf2d:  96% ▕█████████████████ ▏ 5.4 GB/5.6 GB  270 MB/s      0spulling manifest
# pulling 3839a254cf2d:  97% ▕█████████████████ ▏ 5.4 GB/5.6 GB  271 MB/s      0spulling manifest
# pulling 3839a254cf2d:  97% ▕█████████████████ ▏ 5.5 GB/5.6 GB  271 MB/s      0spulling manifest
# pulling 3839a254cf2d:  97% ▕█████████████████ ▏ 5.5 GB/5.6 GB  271 MB/s      0spulling manifest
# pulling 3839a254cf2d:  98% ▕█████████████████ ▏ 5.5 GB/5.6 GB  271 MB/s      0spulling manifest
# pulling 3839a254cf2d:  98% ▕█████████████████ ▏ 5.5 GB/5.6 GB  271 MB/s      0spulling manifest
# pulling 3839a254cf2d:  99% ▕█████████████████ ▏ 5.5 GB/5.6 GB  271 MB/s      0spulling manifest
# pulling 3839a254cf2d: 100% ▕█████████████████ ▏ 5.6 GB/5.6 GB  271 MB/s      0spulling manifest
# pulling 3839a254cf2d: 100% ▕█████████████████ ▏ 5.6 GB/5.6 GB  271 MB/s      0spulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# time=2025-06-29T00:31:48.626Z level=INFO source=download.go:177 msg="downloading e0a42594d802 in 1 358 B part(s)"
# pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# time=2025-06-29T00:31:49.919Z level=INFO source=download.go:177 msg="downloading 1adbfec9dcf0 in 1 8.4 KB part(s)"
# pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# time=2025-06-29T00:31:51.232Z level=INFO source=download.go:177 msg="downloading a3e66f51d60b in 1 417 B part(s)"
# pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B                         pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# ...
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠹ [GIN] 2025/06/29 - 00:32:12 | 200 | 52.112973914s |       127.0.0.1 | POST     "/api/pull"
# pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 3839a254cf2d: 100% ▕██████████████████▏ 5.6 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling 1adbfec9dcf0: 100% ▕██████████████████▏ 8.4 KB
# pulling a3e66f51d60b: 100% ▕██████████████████▏  417 B
# verifying sha256 digest
# writing manifest
# success
# CPU times: user 1.26 s, sys: 307 ms, total: 1.57 s
# Wall time: 52.3 s

# %%
# Função para interagir com o modelo Gemma 3n
def ollama_chat(history, question):
    try:
        # Crafting a prompt to instruct the model
        my_prompt = f"Question: {question}\n"
        
        # Use Ollama chat with the question only
        response = ollama.chat(model='gemma3n:e2b', messages=[
            {
                'role': 'user',
                'content': my_prompt
            },
        ])
        
        answer = response['message']['content']
        # Atualiza o histórico do chat com a nova interação
        history.append(f"<div style='color: blue;'>You: {question}</div>")
        history.append(f"<div style='color: green;'>Gemma 3n: {answer}</div>")
        history_text = "<br>".join(history)
        return history_text, answer
    except Exception as e:
        return history, f"Error occurred: {str(e)}"

# Criação da interface Gradio
with gr.Blocks() as demo:
    history = gr.State([])
    with gr.Column():
        gr.Markdown("# Welcome to the Cruzeta Chat Portal")
        question_input = gr.Textbox(lines=2, label="Ask your question")
        chat_output = gr.HTML(label="Chat History")
        submit_button = gr.Button("Submit")
    
    # Conectar inputs e outputs
    submit_button.click(
        ollama_chat,
        inputs=[history, question_input],
        outputs=[chat_output, gr.Textbox(label="Response", placeholder="Model response will appear here...")]
    )

# Lançar a interface Gradio
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# * Running on public URL: https://270b41f0f8e023dc89.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://270b41f0f8e023dc89.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Function to interact with the Gemma model
def chat_with_gemma(history, image_url, question):
    try:
        # Craft the message content with an image URL
        if image_url:
            message_content = f"You have received an image at the URL: {image_url}. Question: {question or 'Please describe the details of the image.'}"
            
            # Use the Ollama chat with the image and question
            response = ollama.chat(model='gemma3n:e2b', messages=[
                {
                    "role": "user",
                    "content": message_content
                },
            ])
            answer = response['message']['content']
        else:
            response = ollama.chat(model='gemma3n:e2b', messages=[
                {
                    "role": "user",
                    "content": f"Question: {question}"
                }
            ])
            answer = response['message']['content']

        # Update history with the new conversation turn, using HTML for styling
        history.append(f"<div style='color: blue;'>User: {question}</div>")
        history.append(f"<div style='color: green;'>Assistant: {answer}</div>")
        history_text = "<br>".join(history)
        return history_text, answer
    except Exception as e:
        return history, f"Error occurred: {str(e)}"

# Create a Gradio interface using Blocks
with gr.Blocks() as demo:
    history = gr.State([])
    with gr.Column():
        gr.Markdown("# Welcome to Cruzeta Analysis Portal")
        image_url_input = gr.Textbox(lines=1, label="Enter Image URL")  # Changed to accept a URL
        question_input = gr.Textbox(lines=2, label="Ask a question about the image")
        chat_output = gr.HTML(label="Chat History")
        submit_button = gr.Button("Submit")

    # Connect the inputs and outputs
    submit_button.click(
        chat_with_gemma,
        inputs=[history, image_url_input, question_input],
        outputs=[chat_output, gr.Textbox(label="Response", placeholder="Model response will appear here...")]
    )

# Launch the Gradio interface
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# * Running on public URL: https://ae93dd63f84f519515.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ae93dd63f84f519515.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
